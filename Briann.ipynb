# %%
import numpy as np
import pandas as pd

# %%
userdataobj = pd.read_csv('mydata.csv')

# %%
userdataobj
# Out:
#         user_id  item_id  rating  timestamp
# 0             0       50       5  881250949
# 1             0      172       5  881250949
# 2             0      133       1  881250949
# 3           196      242       3  881250949
# 4           186      302       3  891717742
# 5            22      377       1  878887116
# 6           244       51       2  880606923
# 7           166      346       1  886397596
# 8           298      474       4  884182806
# 9           115      265       2  881171488
# 10          253      465       5  891628467
# 11          305      451       3  886324817
# 12            6       86       3  883603013
# 13           62      257       2  879372434
# 14          286     1014       5  879781125
# 15          200      222       5  876042340
# 16          210       40       3  891035994
# 17          224       29       3  888104457
# 18          303      785       3  879485318
# 19          122      387       5  879270459
# ...

# %%
userdataobj.shape
# Out:
# (100003, 4)

# %%
moviedataobj = pd.read_csv('Movie_Id_Titles.csv')

# %%
moviedataobj
# Out:
#       item_id                                              title
# 0           1                                   Toy Story (1995)
# 1           2                                   GoldenEye (1995)
# 2           3                                  Four Rooms (1995)
# 3           4                                  Get Shorty (1995)
# 4           5                                     Copycat (1995)
# 5           6  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 6           7                              Twelve Monkeys (1995)
# 7           8                                        Babe (1995)
# 8           9                            Dead Man Walking (1995)
# 9          10                                 Richard III (1995)
# 10         11                               Seven (Se7en) (1995)
# 11         12                         Usual Suspects, The (1995)
# 12         13                            Mighty Aphrodite (1995)
# ...

# %%
moviedataobj.shape
# Out:
# (1682, 2)

# %%
users = userdataobj['user_id'].unique()
#getting unique users

# %%
len(users)
#getting number of unique users
# Out:
# 944

# %%
moviess = moviedataobj['item_id'].unique()
#getting the unique movies

# %%
len(moviess)
#printing the number of unique movies
# Out:
# 1682

# %%
dfmerged = pd.merge(userdataobj,moviedataobj,on='item_id')

# %%
dfmerged
# Out:
#         user_id  item_id  rating  timestamp  \
# 0             0       50       5  881250949
# 1           290       50       5  880473582
# 2            79       50       4  891271545
# 3             2       50       5  888552084
# 4             8       50       5  879362124
# 5           274       50       5  878944679
# 6           227       50       4  879035347
# 7            99       50       5  885679998
# 8           305       50       5  886321799
# 9           108       50       4  879879739
# 10           63       50       4  875747292
# 11          234       50       4  892079237
# 12           97       50       5  884239471
# 13          117       50       5  880126022
# 14           70       50       4  884064188
# 15          318       50       2  884495696
# 16          145       50       5  885557660
# 17          124       50       3  890287508
# 18          253       50       4  891628518
# 19          271       50       5  885848640
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
dfmerged.sort_values('user_id')
# Out:
#        user_id  item_id  rating  timestamp  \
# 0            0       50       5  881250949
# 952          0      133       1  881250949
# 584          0      172       5  881250949
# 69223        1       72       4  878542678
# 35889        1       82       5  878542589
# 88080        1      124       5  875071484
# 17868        1      174       5  875073198
# 36336        1        3       4  878542960
# 36457        1      198       5  878542717
# 17606        1      132       4  878542889
# 47923        1       80       4  876893008
# 36492        1      189       3  888732928
# 16068        1       23       4  875072895
# 55494        1       55       5  875072688
# 48103        1      238       4  875072235
# 16742        1      208       5  878542960
# 64196        1      179       3  875072370
# 55756        1      121       4  875071823
# 89135        1      159       3  875073180
# 69130        1       87       5  878543541
# 76002        1      253       5  874965970
# ...

# %%
dfmerged.groupby(['user_id']).mean()['rating']
# get the average ratings each user gives an item
# Out:
# user_id
# 0      3.666667
# 1      3.610294
# 2      3.709677
# 3      2.796296
# 4      4.333333
# 5      2.874286
# 6      3.635071
# 7      3.965261
# 8      3.796610
# 9      4.272727
# 10     4.206522
# 11     3.464088
# 12     4.392157
# 13     3.097484
# 14     4.091837
# 15     2.875000
# 16     4.328571
# 17     3.035714
# 18     3.880866
# 19     3.550000
# 20     3.104167
# 21     2.670391
# 22     3.351562
# 23     3.635762
# 24     4.323529
# 25     4.051282
# 26     2.943925
# 27     3.240000
# 28     3.721519
# 29     3.647059
#          ...
# 914    3.086957
# 915    3.115385
# 916    3.365931
# 917    3.542857
# 918    3.349515
# 919    3.470046
# 920    3.230769
# 921    3.272727
# 922    3.370079
# 923    4.148649
# 924    3.756098
# 925    3.125000
# 926    3.300000
# 927    3.691667
# 928    4.687500
# 929    3.693878
# 930    2.968254
# 931    3.721311
# 932    3.966805
# 933    2.646739
# 934    3.701149
# 935    3.923077
# 936    3.746479
# 937    3.375000
# ...

# %%
dfmerged.groupby( 'title' )['rating'].mean()
# Out:
# title
# 'Til There Was You (1997)                                   2.333333
# 1-900 (1994)                                                2.600000
# 101 Dalmatians (1996)                                       2.908257
# 12 Angry Men (1957)                                         4.344000
# 187 (1997)                                                  3.024390
# 2 Days in the Valley (1996)                                 3.225806
# 20,000 Leagues Under the Sea (1954)                         3.500000
# 2001: A Space Odyssey (1968)                                3.969112
# 3 Ninjas: High Noon At Mega Mountain (1998)                 1.000000
# 39 Steps, The (1935)                                        4.050847
# 8 1/2 (1963)                                                3.815789
# 8 Heads in a Duffel Bag (1997)                              3.250000
# 8 Seconds (1994)                                            3.750000
# ...

# %%
dfmerged.groupby(['title', 'item_id']).mean()['rating'].sort_values(ascending=False)
# gets the average ratings each items is given
# Out:
# title                                                   item_id
# Prefontaine (1997)                                      1189       5.000000
# Someone Else's America (1995)                           1599       5.000000
# Marlene Dietrich: Shadow and Light (1996)               1201       5.000000
# Entertaining Angels: The Dorothy Day Story (1996)       1653       5.000000
# They Made Me a Criminal (1939)                          1122       5.000000
# Great Day in Harlem, A (1994)                           814        5.000000
# Star Kid (1997)                                         1293       5.000000
# Aiqing wansui (1994)                                    1536       5.000000
# Saint of Fort Washington, The (1993)                    1467       5.000000
# Santa with Muscles (1996)                               1500       5.000000
# Pather Panchali (1955)                                  1449       4.625000
# ...

# %%
dfmerged.groupby( 'item_id', )['rating'].count().sort_values(ascending=False)
#number of ratings each movie has been rated  in a descending order
# Out:
# item_id
# 50      584
# 258     509
# 100     508
# 181     507
# 294     485
# 286     481
# 288     478
# 1       452
# 300     431
# 121     429
# 174     420
# 127     413
# 56      394
# 7       392
# 98      390
# 237     384
# 117     378
# 172     368
# 222     365
# 313     350
# 204     350
# 405     344
# 79      336
# 210     331
# 151     326
# 173     324
# 69      321
# 168     316
# 748     316
# 269     315
#        ...
# 1414      1
# 1606      1
# 1156      1
# 1681      1
# 857       1
# 1613      1
# 711       1
# 1614      1
# 1236      1
# 1616      1
# 1596      1
# 677       1
# 1580      1
# 1595      1
# 1581      1
# 1582      1
# 1583      1
# 1584      1
# 1586      1
# 1587      1
# 1461      1
# 1460      1
# 1458      1
# 1457      1
# 1453      1
# 1452      1
# 1593      1
# 1447      1
# 814       1
# 1682      1
# Name: rating, Length: 1682, dtype: int64

# %%
dfmerged.groupby( 'user_id' )['rating'].count().sort_values(ascending=False)
#number of ratings each user has rated in a descending order
# Out:
# user_id
# 405    737
# 655    685
# 13     636
# 450    540
# 276    518
# 416    493
# 537    490
# 303    484
# 234    480
# 393    448
# 181    435
# 279    434
# 429    414
# 846    405
# 7      403
# 94     400
# 682    399
# 308    397
# 92     388
# 293    388
# 222    387
# 201    386
# 59     382
# 435    379
# 378    375
# 880    368
# 417    365
# 896    362
# 592    360
# 796    358
#       ...
# 242     20
# 19      20
# 202     20
# 866     20
# 873     20
# 895     20
# 300     20
# 36      20
# 364     20
# 824     20
# 732     20
# 685     20
# 740     20
# 93      20
# 636     20
# 631     20
# 596     20
# 572     20
# 571     20
# 558     20
# 143     20
# 809     20
# 147     20
# 812     20
# 475     20
# 441     20
# 34      20
# 418     20
# 166     20
# 0        3
# Name: rating, Length: 944, dtype: int64

# %%
dfmerged
# Out:
#         user_id  item_id  rating  timestamp  \
# 0             0       50       5  881250949
# 1           290       50       5  880473582
# 2            79       50       4  891271545
# 3             2       50       5  888552084
# 4             8       50       5  879362124
# 5           274       50       5  878944679
# 6           227       50       4  879035347
# 7            99       50       5  885679998
# 8           305       50       5  886321799
# 9           108       50       4  879879739
# 10           63       50       4  875747292
# 11          234       50       4  892079237
# 12           97       50       5  884239471
# 13          117       50       5  880126022
# 14           70       50       4  884064188
# 15          318       50       2  884495696
# 16          145       50       5  885557660
# 17          124       50       3  890287508
# 18          253       50       4  891628518
# 19          271       50       5  885848640
# ...

# %%
# STORING THE AGGREGATED MATERIAL IN A DATAFRAME e.g. Storeddf

# %%
# dfmerged.groupby( 'title' )['rating'].mean()
# meeanrating = pd.DataFrame(the aggregated here)
titemeanrating = pd.DataFrame(dfmerged.groupby( ['title', 'item_id'] )['rating'].mean())

# %%
titemeanrating['item_id'] = titemeanrating.index.get_level_values(1)

# %%
titemeanrating['movietitle'] = titemeanrating.index.get_level_values(0)

# %%
titemeanrating['num_of_rating'] = pd.DataFrame(dfmerged.groupby(['title', 'item_id'] )['rating'].count())

# %%
titemeanrating.head()
# Out:
#                                      rating  item_id  \
# title                     item_id
# 'Til There Was You (1997) 1300     2.333333     1300
# 1-900 (1994)              1353     2.600000     1353
# 101 Dalmatians (1996)     225      2.908257      225
# 12 Angry Men (1957)       178      4.344000      178
# 187 (1997)                330      3.024390      330
#
#                                                   movietitle  num_of_rating
# title                     item_id
# 'Til There Was You (1997) 1300     'Til There Was You (1997)              9
# 1-900 (1994)              1353                  1-900 (1994)              5
# 101 Dalmatians (1996)     225          101 Dalmatians (1996)            109
# 12 Angry Men (1957)       178            12 Angry Men (1957)            125
# 187 (1997)                330                     187 (1997)             41

# %%
titemeanrating.to_csv('foranalysis.csv', index=False)

# %%
foranalysis = pd.read_csv('foranalysis.csv')

# %%
foranalysis.head()
# Out:
#      rating  item_id                 movietitle  num_of_rating
# 0  2.333333     1300  'Til There Was You (1997)              9
# 1  2.600000     1353               1-900 (1994)              5
# 2  2.908257      225      101 Dalmatians (1996)            109
# 3  4.344000      178        12 Angry Men (1957)            125
# 4  3.024390      330                 187 (1997)             41

# %%
newfor = foranalysis.head(22)

# %% [markdown]
# ## Data Visualization

# %%
newfor['itemid_as_string'] = newfor['item_id'].apply(str)
# Out:
# C:\Users\brayan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
newfor
# Out:
#       rating  item_id                                   movietitle  \
# 0   2.333333     1300                    'Til There Was You (1997)
# 1   2.600000     1353                                 1-900 (1994)
# 2   2.908257      225                        101 Dalmatians (1996)
# 3   4.344000      178                          12 Angry Men (1957)
# 4   3.024390      330                                   187 (1997)
# 5   3.225806     1011                  2 Days in the Valley (1996)
# 6   3.500000      141          20,000 Leagues Under the Sea (1954)
# 7   3.969112      135                 2001: A Space Odyssey (1968)
# 8   1.000000      314  3 Ninjas: High Noon At Mega Mountain (1998)
# 9   4.050847      615                         39 Steps, The (1935)
# 10  3.815789     1021                                 8 1/2 (1963)
# 11  3.250000     1664               8 Heads in a Duffel Bag (1997)
# 12  3.750000     1443                             8 Seconds (1994)
# ...

# %%
plt.figure(figsize=(15, 5))
plt.plot(newfor.itemid_as_string, newfor.num_of_rating, 'b.-', label='Movies')

# %%
plt.figure(figsize=(10,7))
mybins=[1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]
#plt.hist(foranalysis.rating, bins =mybins)
plt.hist(foranalysis.rating, color='#6833ff')

plt.xlabel('Ratings the movies Recieved')
plt.ylabel('Total Movies in that range')
plt.title('Distribution graph of Rating')

plt.show()

# %%
newfor2 = foranalysis.head(8)

# %%
newfor2
# Out:
#      rating  item_id                           movietitle  num_of_rating
# 0  2.333333     1300            'Til There Was You (1997)              9
# 1  2.600000     1353                         1-900 (1994)              5
# 2  2.908257      225                101 Dalmatians (1996)            109
# 3  4.344000      178                  12 Angry Men (1957)            125
# 4  3.024390      330                           187 (1997)             41
# 5  3.225806     1011          2 Days in the Valley (1996)             93
# 6  3.500000      141  20,000 Leagues Under the Sea (1954)             72
# 7  3.969112      135         2001: A Space Odyssey (1968)            259

# %%
plt.figure(figsize=(8,8))
mylabels = newfor2.movietitle
plt.pie(newfor2.num_of_rating, labels = mylabels)
plt.show()

# %%
watu= titemeanrating[['movietitle','item_id', 'num_of_rating']]

# %%
# dfmerged.groupby( 'title' )['rating'].mean()
# meeanrating = pd.DataFrame(the aggregated here)
itemeanrating = pd.DataFrame(dfmerged.groupby( ['title', 'item_id'] )['rating'].mean())

# %%
itemeanrating
# Out:
#                                                               rating  \
# title                                              item_id
# 'Til There Was You (1997)                          1300     2.333333
# 1-900 (1994)                                       1353     2.600000
# 101 Dalmatians (1996)                              225      2.908257
# 12 Angry Men (1957)                                178      4.344000
# 187 (1997)                                         330      3.024390
# 2 Days in the Valley (1996)                        1011     3.225806
# 20,000 Leagues Under the Sea (1954)                141      3.500000
# 2001: A Space Odyssey (1968)                       135      3.969112
# 3 Ninjas: High Noon At Mega Mountain (1998)        314      1.000000
# 39 Steps, The (1935)                               615      4.050847
# 8 1/2 (1963)                                       1021     3.815789
# 8 Heads in a Duffel Bag (1997)                     1664     3.250000
# ...

# %%
# code for droping a column
# itemeanrating = itemeanrating.drop(columns=['num of ratings'])

# %%
# Adding a column in the itemeanrating to include the number of times it has been rated
itemeanrating['num_of_rating'] = pd.DataFrame(dfmerged.groupby('title')['rating'].count())

# %%
#tempee = pd.DataFrame(dfmerged.groupby('title')['rating'].count())

# %%
#tempee['num_of_rating'] = pd.DataFrame(dfmerged.groupby('title')['rating'].count())

# %%
#tempee
# Out:
#                                                     rating  num_of_rating
# title
# 'Til There Was You (1997)                                9              9
# 1-900 (1994)                                             5              5
# 101 Dalmatians (1996)                                  109            109
# 12 Angry Men (1957)                                    125            125
# 187 (1997)                                              41             41
# 2 Days in the Valley (1996)                             93             93
# 20,000 Leagues Under the Sea (1954)                     72             72
# 2001: A Space Odyssey (1968)                           259            259
# 3 Ninjas: High Noon At Mega Mountain (1998)              5              5
# 39 Steps, The (1935)                                    59             59
# 8 1/2 (1963)                                            38             38
# 8 Heads in a Duffel Bag (1997)                           4              4
# ...

# %%
itemeanrating['movietitle'] = itemeanrating.index

# %%
usermeanratin = pd.DataFrame(dfmerged.groupby( 'user_id' )['rating'].mean())

# %%
usermeanratin
# Out:
#            rating
# user_id
# 0        3.666667
# 1        3.610294
# 2        3.709677
# 3        2.796296
# 4        4.333333
# 5        2.874286
# 6        3.635071
# 7        3.965261
# 8        3.796610
# 9        4.272727
# 10       4.206522
# 11       3.464088
# 12       4.392157
# 13       3.097484
# 14       4.091837
# 15       2.875000
# 16       4.328571
# 17       3.035714
# 18       3.880866
# 19       3.550000
# 20       3.104167
# 21       2.670391
# 22       3.351562
# 23       3.635762
# 24       4.323529
# 25       4.051282
# 26       2.943925
# 27       3.240000
# 28       3.721519
# 29       3.647059
# ...           ...
# 914      3.086957
# 915      3.115385
# 916      3.365931
# 917      3.542857
# 918      3.349515
# 919      3.470046
# 920      3.230769
# 921      3.272727
# 922      3.370079
# 923      4.148649
# 924      3.756098
# 925      3.125000
# 926      3.300000
# 927      3.691667
# 928      4.687500
# 929      3.693878
# 930      2.968254
# ...

# %%
dfmerged
# Out:
#         user_id  item_id  rating  timestamp  \
# 0             0       50       5  881250949
# 1           290       50       5  880473582
# 2            79       50       4  891271545
# 3             2       50       5  888552084
# 4             8       50       5  879362124
# 5           274       50       5  878944679
# 6           227       50       4  879035347
# 7            99       50       5  885679998
# 8           305       50       5  886321799
# 9           108       50       4  879879739
# 10           63       50       4  875747292
# 11          234       50       4  892079237
# 12           97       50       5  884239471
# 13          117       50       5  880126022
# 14           70       50       4  884064188
# 15          318       50       2  884495696
# 16          145       50       5  885557660
# 17          124       50       3  890287508
# 18          253       50       4  891628518
# 19          271       50       5  885848640
# ...

# %% [markdown]
# ## Building Recommender

# %%
myanalays = dfmerged.pivot_table(index='user_id',columns='title',values='rating')

# %%
myanalays
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# 6                              NaN           NaN                    NaN
# 7                              NaN           NaN                    NaN
# 8                              NaN           NaN                    NaN
# 9                              NaN           NaN                    NaN
# 10                             NaN           NaN                    NaN
# 11                             NaN           NaN                    NaN
# ...

# %%
#the ratings users give to movie star wars
ratings_users_Starwars = myanalays['Star Wars (1977)']

# %%
#printing this ratings 
ratings_users_Starwars
# Out:
# user_id
# 0      5.0
# 1      5.0
# 2      5.0
# 3      NaN
# 4      5.0
# 5      4.0
# 6      4.0
# 7      5.0
# 8      5.0
# 9      5.0
# 10     5.0
# 11     NaN
# 12     4.0
# 13     5.0
# 14     5.0
# 15     5.0
# 16     NaN
# 17     NaN
# 18     4.0
# 19     NaN
# 20     3.0
# 21     3.0
# 22     5.0
# 23     4.0
# 24     NaN
# 25     5.0
# 26     4.0
# 27     3.0
# 28     4.0
# 29     NaN
#       ...
# 914    NaN
# 915    NaN
# 916    5.0
# 917    3.0
# 918    NaN
# 919    3.0
# 920    NaN
# 921    4.0
# 922    5.0
# 923    5.0
# 924    5.0
# 925    NaN
# 926    NaN
# 927    NaN
# 928    NaN
# 929    4.0
# 930    2.0
# 931    3.0
# 932    NaN
# 933    4.0
# 934    5.0
# 935    NaN
# 936    4.0
# 937    5.0
# 938    5.0
# 939    NaN
# 940    4.0
# 941    NaN
# 942    5.0
# 943    4.0
# Name: Star Wars (1977), Length: 944, dtype: float64

# %%
#how this rating correlate with other ratings 
similar_to_starwars = myanalays.corrwith(ratings_users_Starwars)
# Out:
# C:\Users\brayan\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\brayan\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
similar_to_starwars
# Out:
# title
# 'Til There Was You (1997)                                   0.872872
# 1-900 (1994)                                               -0.645497
# 101 Dalmatians (1996)                                       0.211132
# 12 Angry Men (1957)                                         0.184289
# 187 (1997)                                                  0.027398
# 2 Days in the Valley (1996)                                 0.066654
# 20,000 Leagues Under the Sea (1954)                         0.289768
# 2001: A Space Odyssey (1968)                                0.230884
# 3 Ninjas: High Noon At Mega Mountain (1998)                      NaN
# 39 Steps, The (1935)                                        0.106453
# 8 1/2 (1963)                                               -0.142977
# 8 Heads in a Duffel Bag (1997)                             -0.577350
# 8 Seconds (1994)                                           -0.755929
# ...

# %%
mycorr_starwars = similar_to_starwars

# %%
mycorr_starwars
# Out:
# title
# 'Til There Was You (1997)                                   0.872872
# 1-900 (1994)                                               -0.645497
# 101 Dalmatians (1996)                                       0.211132
# 12 Angry Men (1957)                                         0.184289
# 187 (1997)                                                  0.027398
# 2 Days in the Valley (1996)                                 0.066654
# 20,000 Leagues Under the Sea (1954)                         0.289768
# 2001: A Space Odyssey (1968)                                0.230884
# 3 Ninjas: High Noon At Mega Mountain (1998)                      NaN
# 39 Steps, The (1935)                                        0.106453
# 8 1/2 (1963)                                               -0.142977
# 8 Heads in a Duffel Bag (1997)                             -0.577350
# 8 Seconds (1994)                                           -0.755929
# ...

# %%
mycorr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])

# %%
#droping the null values
mycorr_starwars.dropna(inplace=True)

# %%
mycorr_starwars =  mycorr_starwars.join(tempee['num_of_rating'])

# %%
mycorr_starwars.head()
# Out:
#                            Correlation  num_of_rating
# title
# 'Til There Was You (1997)     0.872872              9
# 1-900 (1994)                 -0.645497              5
# 101 Dalmatians (1996)         0.211132            109
# 12 Angry Men (1957)           0.184289            125
# 187 (1997)                    0.027398             41

# %%
mycorr_starwars.loc[mycorr_starwars['num_of_rating'] > 320].sort_values('Correlation',ascending=False)
# Out:
#                                               Correlation  num_of_rating
# title
# Star Wars (1977)                                 1.000000            584
# Empire Strikes Back, The (1980)                  0.748353            368
# Return of the Jedi (1983)                        0.672556            507
# Raiders of the Lost Ark (1981)                   0.536117            420
# Indiana Jones and the Last Crusade (1989)        0.350107            331
# Back to the Future (1985)                        0.274839            350
# Princess Bride, The (1987)                       0.259711            324
# Star Trek: First Contact (1996)                  0.255529            365
# Independence Day (ID4) (1996)                    0.248754            429
# Willy Wonka and the Chocolate Factory (1971)     0.221902            326
# Godfather, The (1972)                            0.189775            413
# Toy Story (1995)                                 0.180020            452
# ...
